# %% [markdown]
# # Google Play Store Exploratory Data Analysis (EDA)
#
# This project analyzes the Google Play Store dataset to identify trends in app ratings, reviews, installs, and categories using Python.

# %%
# Pandas--Google Play Store App Analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('Display.max_columns',None)

# %%
df = pd.read_csv('googleplaystore.csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## Find the total number of apps in the google playstore

# %%
# Task1: Find the total number of apps in the google playstore
# To find the total number of apps we use shape attribute
print('Total number of apps in playstore =',df.shape[0]) # The 0 refers to the rows in the csv file
# Out:
# Total number of apps in playstore = 10841

# %% [markdown]
# ## Find the total number of columns in each app of google playstore

# %%
# Task2: Find the total number of columns in each app of google playstore
# To find the total number of columns for each app we use shape attribute
print('Total number of columns in each app of google playstore =',df.shape[1]) # The 1 refers to total number of columns in csv file
# Out:
# Total number of columns in each app of google playstore = 13

# %% [markdown]
# ## Display top 5 rows of the dataset

# %%
# Task3: Display top 5 rows of the dataset
# Using head() function we can access top 5 rows of a dataset
# We can also use loc or iloc functions 
print('-----------------------------------------------------------------------------------------')
print('Top 5 Rows of the Dataset')
print('-----------------------------------------------------------------------------------------')
print(df.head())
print('-----------------------------------------------------------------------------------------')
# Out:
# -----------------------------------------------------------------------------------------
# Top 5 Rows of the Dataset
# -----------------------------------------------------------------------------------------
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# ...

# %% [markdown]
# ## Check the last 3 rows of the Dataset

# %%
# Task 4: Check the last 3 rows of the Dataset
# To access the last 3 rows of dataset tail() function can be used
print('-----------------------------------------------------------------------------------------')
print('Least 3 Rows of the Dataset')
print('-----------------------------------------------------------------------------------------')
print(df.tail(3))
print('-----------------------------------------------------------------------------------------')
# Out:
# -----------------------------------------------------------------------------------------
# Least 3 Rows of the Dataset
# -----------------------------------------------------------------------------------------
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# ...

# %% [markdown]
# ## Find the shape of our Dataset

# %%
# Task 5: Find the shape of our Dataset (Number of Rows and Number of Columns)
# We use shape attribute to access number of columns and rows in a dataset

print('Number of Rows and Columns =',df.shape)
# Out:
# Number of Rows and Columns = (10841, 13)

# %% [markdown]
# ## Get information about our dataset like total number of rows and total number of columns and Datatypes of Each Column and Memory Requirement

# %%
# Task 6: Get information about our dataset like total number of rows and total number of columns Datatypes of Each Column and Memory Requirement
# To access the information like number of non null values dtype of each column and shape of the data set
# We use info() function
print('--------------------------------------------------')
print('Information about the Dataset')
print('--------------------------------------------------')
df.info()
print('--------------------------------------------------')
# Out:
# --------------------------------------------------
# Information about the Dataset
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB
# ...

# %% [markdown]
# ## Get overall statistics of Dataset

# %%
'''
# Task 7: Get overall statistics of Dataset
           OR 
# Get the descriptive statistics about Google Play Store
'''
# describe() is a function used to deisplay the numerical stats of dataset
# df.describe(include = 'all') used to display over all stats
print('Statistical description of Google Playstore')

df.describe(include = 'all')
# Out:
# Statistical description of Google Playstore
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# ## Obtain total number of apps contain astrology

# %%
# Task 8: Obtain total number of apps contain astrology
# To obtain number of apps containing Astrology
# Access the apps containing Astrology-->Return an ndarray
# len of the array will give the total number of apps
print('Apps containing Astrology')
print('---------------------------------------------------------')
print((df[(df['App'].str.contains('Astrology'))]['App']).values)
print('---------------------------------------------------------')
print('Number of apps containing Astrology =',len((df[(df['App'].str.contains('Astrology'))]['App']).values))
# Out:
# Apps containing Astrology
# ---------------------------------------------------------
# ['Horoscopes – Daily Zodiac Horoscope and Astrology'
#  'သိင်္ Astrology - Min Thein Kha BayDin'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']
# ---------------------------------------------------------
# Number of apps containing Astrology = 3

# %% [markdown]
# ## Find average app Rating in Google Play Store

# %%
# Task 9: Find the average app rating in google play store
# First access the Rating column --> Using mean() helps to obtain average rtating of the apps
print('Average App rating =',df['Rating'].mean())
# Out:
# Average App rating = 4.193338315362443

# %% [markdown]
# ## Find the total number of unique category apps

# %%
# Task 10: Find the number of unique values Category
# Method 1:
# Access the Category column then using unique() returns ndarray of unique values --> then len(ndarray) gives number of unique values
print('Number of unique values in Category =',len(df['Category'].unique()))
# Out:
# Number of unique values in Category = 34

# %%
# Method 2:
# Access the Category column and use nunique
print('Number of unique values in Category =',df['Category'].nunique())
# Out:
# Number of unique values in Category = 34

# %% [markdown]
# ## Find the Category with the Highest Average Rating

# %%
# Task 11 : Find the category with the highest average rating
# Group by category and calculate mean ratings sort the values in descending order access the top Category
# This give a series dtype with Category and top rating
# Accessing the index of that series gives us Category name 
rating = df.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(1)
print('Highest average rating of app')
print('---------------------------------------------------------------------------------')
print(rating)
print('---------------------------------------------------------------------------------')
print('Category with highest average rating')
print('---------------------------------------------------------------------------------')
rating.index[0]
# Out:
# Highest average rating of app
# ---------------------------------------------------------------------------------
# Category
# 1.9    19.0
# Name: Rating, dtype: float64
# ---------------------------------------------------------------------------------
# Category with highest average rating
# ---------------------------------------------------------------------------------
# '1.9'

# %% [markdown]
# ## Find the number of apps with 5 star rating

# %%
# Task 12: Find the number of apps with 5 star rating
# We filter the dataset using condition
# Access the Apps with Rating of 5 retuns a data set --> len() the data gives number of apps
# sum() dataset can be used to find number of apps rated with 5 stars
apps = df[df['Rating']==5]
print('Number of apps achieved 5 star rating in google playstore =',len(apps))
print('------------------------------------------------------------------------')
rating = df['Rating']==5 # Returns bool
print('Number of apps achieved 5 star rating in google playstore =',(rating).sum())
# Out:
# Number of apps achieved 5 star rating in google playstore = 274
# ------------------------------------------------------------------------
# Number of apps achieved 5 star rating in google playstore = 274

# %% [markdown]
# ## Data Cleaning and Preprocessing
#
# The raw dataset contained inconsistent formats and invalid entries. The following corrections were performed to prepare the data for analysis.

# %% [markdown]
# ## Find the average value of reviews

# %%
# Task 13: Find the average value of reviews
# To obtain average reviews of apps in google playstore we should access the Reviews column
# Replace the strings with numerical values
# Convert the whole Reviews data to Float then find the mean
df['Reviews'].replace('3.0M','3000000',inplace=True)
print('Average value of Reviews =',df['Reviews'].astype(float).mean())
# Out:
# Average value of Reviews = 444388.6535374965

# %% [markdown]
# ## Find the total number of Free paid apps

# %%
# Task 14: Find the total number of free paid apps
# To find the number of free apps available in the google playstore
# Access the Type(it describes the app paid/free) column
# Search for free then -->len(free_apps)
df.loc[10472,'Type']=df.loc[10472,'Type'].replace('0','Free')
free_apps = df[df['Type']=='Free']
print('Number of apps available for free in google playstore =',len(free_apps))
# Out:
# Number of apps available for free in google playstore = 10040

# %%
print('Total number of paid apps available in google playstore',(df['Type']=='Paid').sum())
# Out:
# Total number of paid apps available in google playstore 800

# %%
df['Type'].value_counts()
# Out:
# Type
# Free    10040
# Paid      800
# Name: count, dtype: int64

# %% [markdown]
# ## Find the app with maximum reviews

# %%
# Task 15: Find the app with maximum reviews
# Access the Reviews column and then find the max values in reviews column
# Using the max value we can access the App name
# Since it is a series dtype we use values attribute to obtain name
highest = df['Reviews'].max()
print('Maximum reviews =',highest)
print('--------------------------------------------------')
print('App with maximum reviews =', df[df['Reviews']==df['Reviews'].max()]['App'])
# Out:
# Maximum reviews = 9992
# --------------------------------------------------
# App with maximum reviews = 2989    GollerCepte Live Score
# Name: App, dtype: object

# %% [markdown]
# ## Display top 5 apps having highest reviews

# %%
# Task 16: Find the top 5 apps having highest reviews
# To obtain the top 5 apps with highest reviews should sort reviews column values in descending order
# Obtain top 5 apps index values using head() function
# Using loc or iloc --> df.iloc[index] gives us apps data
# Then access the app column

ind = df['Reviews'].astype(float).sort_values(ascending=False).head().index
print('Top 5 Apps with highest reviews')
print('-------------------------------------------------------')
print(df.iloc[ind]['App'])
# Out:
# Top 5 Apps with highest reviews
# -------------------------------------------------------
# 2544              Facebook
# 3943              Facebook
# 381     WhatsApp Messenger
# 336     WhatsApp Messenger
# 3904    WhatsApp Messenger
# Name: App, dtype: object

# %% [markdown]
# ## Display top 5 apps having maximum number of installs

# %%
# Task 17: Find the top 5 apps with highest number of installs
# Obtain the installs column from dataset
# Convert the Installs column values to int 
# Replace ',' and '+' using replace() function
# Sort the values in installs column, using head() obtain top 5 installs and using index attribute obtain indices of the apps
# Using those indices then obtain the top 5 apps with maximum installs
df['Installs'] = df['Installs'].str.replace(',','')
df['Installs'] = df['Installs'].str.replace('+','')
df['Installs'] = df['Installs'].str.replace('Free','0')
df['Installs'] = df['Installs'].astype(int)
index_val = df['Installs'].sort_values(ascending = False).head().index
print('Top 5 apps with maximum number of installs')
print('------------------------------------------')
print(df.loc[index_val]['App'])
# Out:
# Top 5 apps with maximum number of installs
# ------------------------------------------
# 5856    Google Play Games
# 5395        Google Photos
# 2853        Google Photos
# 2884        Google Photos
# 4170         Google Drive
# Name: App, dtype: object

# %% [markdown]
# ## Find the average rating of free and paid apps

# %%
# Task 18: Find the average rating of free and paid apps
# To obtain the average Rating of free and paid apps we use groupby() finction
# groupby('Type') and obtain the mean for Rating column
print('Average rating of Free and paid Apps')
print('-----------------------------------------')
print(df.groupby('Type')['Rating'].mean())
# Out:
# Average rating of Free and paid Apps
# -----------------------------------------
# Type
# Free    4.187901
# Paid    4.266615
# Name: Rating, dtype: float64

# %% [markdown]
# ## Create a bar chart showing the top 10 categories having the highest number of apps.

# %%
# Task 19: Visualize a bar graph of the top 10 categories app installations
# To visualize the top 10 categories app installations
# Access the top 10 categories then use plt.bar() to visualize bar graph
top_apps = df['Category'].value_counts().head(10)
plt.figure(figsize=(18,5))
plt.bar(top_apps.index,top_apps.values)
plt.xlabel('App category')
plt.ylabel('Number of Apps')
plt.title('Categories in the Googleplaystore',fontdict={'family':'calibri','size':25})
plt.show()

# %% [markdown]
# ## Display the number of apps under each Content Rating.

# %%
# Task 20: Display the number of apps under each Content Rating
# To display the number of apps under each content rating access the content ratings value_counts
# Use plt.bar() to visualize a bar graph
rating = df['Content Rating'].value_counts()
plt.figure(figsize=(10,5))
plt.bar(rating.index,rating.values)
plt.xlabel('Content Rating')
plt.ylabel('Number of ratings')
plt.title('Content Ratings given to the apps')
plt.show()

# %% [markdown]
# ## Visualize a pie chart for Free and Paid apps

# %%
# Task 21: Visualize a pie chart for Free and Paid apps
# To visualize a pie chart Free vs Paid apps
# We use plt.pie() to visualize a pie chart
app_type = df['Type'].value_counts()
plt.pie(app_type.values,labels=app_type.index,autopct='%0.2f%%')
plt.title('Free and Paid apps available in the Playstore')
plt.show()

# %% [markdown]
# ## Visualize Average Installs Across Top 5 Categories

# %%
# Task 22: Visualize Average Installs Across Top 5 Categories
# To visualize the average installs across the top 5 categories
# We use plt.bar() to visualize a bar graph
Apps = df.groupby('Category')['Installs'].mean().sort_values(ascending=False).head()
plt.figure(figsize=(8,5))
plt.bar(Apps.index,Apps.values)
plt.xlabel('App Category')
plt.ylabel('Average installs')
plt.title('Average installations across top 5 categories')
plt.show()

# %% [markdown]
# ## Visualize a Histogram for Distribution of App Ratings

# %%
# Task 23: Visualize a histogram for Distribution of app rating in google play store
# To  visualize the distribution of app rating
# We use plt.hist() to visualize a histogram
ratings = df['Rating'].dropna()
plt.figure(figsize=(8,5))
plt.hist(ratings, bins=15)
plt.title("Distribution of App Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Conclusion
#
# - Family and Game categories contained the most applications.
# - Most apps had ratings between 4.0 and 4.5.
# - Apps with more installs generally received more reviews, indicating higher user engagement.
# - The Communication category recorded the highest number of installs.
# - More than 90% of apps in the Play Store were available for free.
